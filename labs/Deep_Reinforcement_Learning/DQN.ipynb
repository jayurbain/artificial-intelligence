# %% [markdown]
# ### Deep Q-Learning with Keras and OpenAI
#
# Jay Urbain
#
# This tutorial lab will demonstrate how deep reinforcement learning (deep Q-learning) can be implemented and applied to the *CartPole* game using *Keras* and the *OpenAI Gym*.
#
# This lab consists of four parts:
# - A review of reinforcement learning.
# - Introduction a deep Q-Learning agent that plays the cart pole game using the OpenAI Gym.
# - Experimentation of machine learning hyperparameters to reduce the solution convergence time. Converge will be defined as the number of training epochs until the error is less than $0.01$. I.e., `e: 0.01` in the print statement below.
# - Extension of the Q-Learning agent to play one of the Atari PacMan in the OpenAI Gym playground.
#
#
# <h2 id="References"><a href="#References" class="headerlink" title="References"></a>References</h2><ul>
# <li><a href="https://arxiv.org/abs/1312.5602" target="_blank" rel="external">Playing Atari with Deep Reinforcement Learning</a></li>
# <li><a href="https://www.nature.com/articles/nature14236" target="_blank" rel="external">Human-level Control Through Deep Reinforcement Learning</a></li>
# <li><a href="https://github.com/rlcode/reinforcement-learning" target="_blank" rel="external">Reinforcement Learning Examples by RLCode</a></li>
# <li><a href="https://ai.intel.com/demystifying-deep-reinforcement-learning/" target="_blank" rel="external">Demystifying Deep Reinforcement Learning Part 1</a></li>
# <li><a href="https://ai.intel.com/deep-reinforcement-learning-with-neon/" target="_blank" rel="external">Demystifying Deep Reinforcement Learning with Neon</a></li>
# <li><a href="https://keon.io/" target="_blank" rel="external">Deep Q Learning</a></li>
# </ul>
#
# <img src='images/animation.gif' width='400px'></img>

# %% [markdown]
# ### Reinforcement Learning
#
# <img src='images/rl.png' width=400px></img>
#
# Reinforcement Learning is a type of machine learning where agents learn by interacting with their environment.
#
# For example, we learn to balance and steer a bike by trial and error. As seen in the picture, the brain represents the AI agent, which acts on the environment. After each action, the agent receives feedback. The feedback consists of the reward and next state of the environment. The reward is usually defined by a human. If we use the analogy of the bicycle, we can define reward as the distance from the original starting point.
#
# In the case of the cartpole, the action is left or right position, and the feedback is angle.

# %% [markdown]
# ### Cartpole Game
#
# Usually, training an agent to play an Atari can take several hours or even days. So we will make an agent to play a simpler game called *CartPole*, but using the same idea used in the paper.
#
# CartPole is one of the basic environments in OpenAI gym (a game simulator). As you can see in the animation from the top, the goal of CartPole is to balance a pole connected with one joint on top of a moving cart. Instead of pixel information, there are 4 kinds of information given by the state, such as angle of the pole and position of the cart. An agent can move the cart by performing a series of actions of $0$ or $1$ to the cart, pushing it left or right.
#
# Gym makes interacting with the game environment relatively simple.
# '''
# next_state, reward, done, info = env.step(action)
# '''
#
# An action can be either $0$ or $1$. If we pass an action, env, which represents the game environment, will emit the results. done is a boolean value telling whether the game ended or not. The old state information paired with action and next_state and reward is the information we need for training the agent.
#
# Below is a bare bones model that just takes random actions for 250 interations. You should see a window pop up rendering the classic cart-pole problem.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

import gym
env = gym.make('CartPole-v0')
env.reset()
for _ in range(250):
    env.render()
    env.step(env.action_space.sample()) # take a random action
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# /Users/jayurbain/Dropbox/Reinforcement Learning/gym/gym/__init__.py:22: UserWarning: DEPRECATION WARNING: to improve load times, gym no longer automatically loads gym.spaces. Please run "import gym.spaces" to load gym.spaces on your own. This warning will turn into an error in a future version of gym.
#   warnings.warn('DEPRECATION WARNING: to improve load times, gym no longer automatically loads gym.spaces. Please run "import gym.spaces" to load gym.spaces on your own. This warning will turn into an error in a future version of gym.')
# WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.

# %% [markdown]
# #### Observations
#
# If we ever want to do better than take random actions at each step, it’d probably be good to actually know what our actions are doing to the environment.
#
# The environment’s `step` function returns exactly what we need. In fact, step returns four values. These are:
#
# - `observation` (object): an environment-specific object representing your observation of the environment. For example, pixel data from a camera, joint angles and joint velocities of a robot, or the board state in a board game.
#
# - `reward` (float): amount of reward achieved by the previous action. The scale varies between environments, but the goal is always to increase your total reward.
#
# - `done` (boolean): whether it’s time to `reset` the environment again. Most (but not all) tasks are divided up into well-defined episodes, and `done` being `True` indicates the episode has terminated. (For example, perhaps the pole tipped too far, or you lost your last life.)
#
# - `info` (dict): diagnostic information useful for debugging. It can sometimes be useful for learning (for example, it might contain the raw probabilities behind the environment’s last state change). However, official evaluations of your agent are not allowed to use this for learning.
#
# This is just an implementation of the classic “agent-environment loop”. Each timestep, the agent chooses an `action`, and the environment returns an `observation` and a `reward`.

# %% [markdown]
# <img src='images/aeloop.svg' width=400px></img>
#
# The process gets started by calling reset(), which returns an initial observation. So a more proper way of writing the previous code would be to respect the done flag:

# %%
import gym
env = gym.make('CartPole-v0')
for i_episode in range(20):
    observation = env.reset()
    for t in range(100):
        env.render()
        print(observation)
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break
# Out:
# /Users/jayurbain/Dropbox/Reinforcement Learning/gym/gym/__init__.py:22: UserWarning: DEPRECATION WARNING: to improve load times, gym no longer automatically loads gym.spaces. Please run "import gym.spaces" to load gym.spaces on your own. This warning will turn into an error in a future version of gym.
#   warnings.warn('DEPRECATION WARNING: to improve load times, gym no longer automatically loads gym.spaces. Please run "import gym.spaces" to load gym.spaces on your own. This warning will turn into an error in a future version of gym.')
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# [-0.02602502  0.00482096  0.04032394 -0.0392331 ]
# [-0.0259286   0.19934216  0.03953928 -0.31892569]
# [-0.02194176  0.39387933  0.03316077 -0.59888186]
# [-0.01406417  0.58852201  0.02118313 -0.88093788]
# [-0.00229373  0.3931188   0.00356437 -0.58167145]
# [ 0.00556865  0.58819063 -0.00806906 -0.87322941]
# [ 0.01733246  0.78342136 -0.02553365 -1.16843826]
# [ 0.03300089  0.97886602 -0.04890241 -1.46901576]
# [ 0.05257821  1.17455105 -0.07828273 -1.77656398]
# [ 0.07606923  0.98039329 -0.11381401 -1.50921088]
# [ 0.09567709  0.78681986 -0.14399822 -1.25411843]
# [ 0.11141349  0.98346203 -0.16908059 -1.58821819]
# [ 0.13108273  1.18014127 -0.20084496 -1.92850323]
# Episode finished after 13 timesteps
# [ 0.04984661 -0.01677599 -0.02079201  0.00214552]
# [ 0.04951109 -0.21159368 -0.0207491   0.28819648]
# [ 0.04527922 -0.40641369 -0.01498517  0.57426379]
# [ 0.03715095 -0.21108489 -0.00349989  0.27689802]
# [ 0.03292925 -0.01591318  0.00203807 -0.01688672]
# [ 0.03261098 -0.2110643   0.00170034  0.27643855]
# [ 0.0283897  -0.01596665  0.00722911 -0.01570761]
# [ 0.02807036  0.17905088  0.00691495 -0.30610093]
# [ 0.03165138  0.37407362  0.00079294 -0.59659505]
# [ 0.03913285  0.56918446 -0.01113896 -0.88902811]
# [ 0.05051654  0.76445579 -0.02891953 -1.18519171]
# [ 0.06580566  0.56972064 -0.05262336 -0.90171229]
# [ 0.07720007  0.37534962 -0.07065761 -0.62602348]
# [ 0.08470706  0.18128141 -0.08317808 -0.35640359]
# [ 0.08833269  0.37748137 -0.09030615 -0.67411221]
# [ 0.09588232  0.18372284 -0.10378839 -0.41117264]
# [ 0.09955678  0.38015124 -0.11201185 -0.73468876]
# [ 0.1071598   0.18674026 -0.12670562 -0.47925304]
# [ 0.11089461  0.38340187 -0.13629068 -0.80903252]
# [ 0.11856264  0.58010185 -0.15247133 -1.14129197]
# [ 0.13016468  0.38726531 -0.17529717 -0.90004597]
# [ 0.13790999  0.19489648 -0.19329809 -0.6671887 ]
# [ 0.14180792  0.00291312 -0.20664186 -0.44105329]
# Episode finished after 23 timesteps
# [ 0.04032434 -0.04118261 -0.0296143  -0.04546416]
# [ 0.03950068 -0.23586766 -0.03052359  0.23773004]
# [ 0.03478333 -0.43054055 -0.02576899  0.52063081]
# [ 0.02617252 -0.23506551 -0.01535637  0.21994035]
# [ 0.02147121 -0.03972745 -0.01095756 -0.07754678]
# [ 0.02067666  0.15554985 -0.0125085  -0.37366662]
# [ 0.02378766  0.35084724 -0.01998183 -0.67026718]
# [ 0.0308046   0.15600871 -0.03338718 -0.383942  ]
# [ 0.03392478  0.35158838 -0.04106602 -0.68696202]
# [ 0.04095654  0.1570598  -0.05480526 -0.40748517]
# [ 0.04409774 -0.03724395 -0.06295496 -0.13257183]
# [ 0.04335286 -0.23141026 -0.0656064   0.13960414]
# [ 0.03872466 -0.42553421 -0.06281431  0.41088919]
# [ 0.03021397 -0.22958062 -0.05459653  0.09908321]
# [ 0.02562236 -0.03372043 -0.05261487 -0.21031273]
# [ 0.02494795  0.16211281 -0.05682112 -0.51911771]
# [ 0.02819021 -0.03216508 -0.06720347 -0.24486761]
# [ 0.02754691  0.16384916 -0.07210083 -0.55796823]
# [ 0.03082389 -0.03019054 -0.08326019 -0.28884418]
# [ 0.03022008 -0.2240326  -0.08903707 -0.02353855]
# [ 0.02573943 -0.02775407 -0.08950785 -0.34293243]
# [ 0.02518434  0.1685197  -0.09636649 -0.6624447 ]
# [ 0.02855474  0.36484097 -0.10961539 -0.98384823]
# [ 0.03585156  0.56124711 -0.12929235 -1.30885169]
# [ 0.0470765   0.7577482  -0.15546939 -1.63904929]
# [ 0.06223146  0.95431337 -0.18825037 -1.97586495]
# Episode finished after 26 timesteps
# [-9.43529351e-06  2.69745943e-03  1.35692344e-02  6.50794585e-03]
# [ 4.45138951e-05 -1.92616439e-01  1.36993933e-02  3.03441055e-01]
# [-0.00380781  0.00230762  0.01976821  0.0151099 ]
# [-0.00376166  0.19714058  0.02007041 -0.27127096]
# [ 1.81149066e-04  3.91970464e-01  1.46449932e-02 -5.57556626e-01]
# [ 0.00802056  0.5868838   0.00349386 -0.8455898 ]
# [ 0.01975823  0.78195791 -0.01341794 -1.13717198]
# [ 0.03539739  0.97725277 -0.03616137 -1.43403266]
# [ 0.05494245  1.17280164 -0.06484203 -1.73779333]
# [ 0.07839848  1.36859985 -0.09959789 -2.04992365]
# [ 0.10577048  1.56459132 -0.14059637 -2.37168731]
# [ 0.1370623   1.76065243 -0.18803011 -2.70407634]
# Episode finished after 12 timesteps
# [-0.00873217 -0.02895949  0.04856647 -0.01027972]
# [-0.00931136 -0.22474309  0.04836087  0.29732233]
# [-0.01380622 -0.42051988  0.05430732  0.60485673]
# [-0.02221662 -0.61635755  0.06640445  0.91413867]
# [-0.03454377 -0.4221936   0.08468723  0.64304319]
# [-0.04298765 -0.22834775  0.09754809  0.37818477]
# [-0.0475546  -0.03473671  0.10511179  0.11778254]
# [-0.04824933 -0.23119538  0.10746744  0.44169011]
# [-0.05287324 -0.03774526  0.11630124  0.18472362]
# [-0.05362815  0.15553719  0.11999571 -0.06912598]
# [-0.0505174   0.34875266  0.11861319 -0.32167098]
# [-0.04354235  0.54200337  0.11217977 -0.57471972]
# [-0.03270228  0.73538872  0.10068538 -0.83006271]
# [-0.01799451  0.92900087  0.08408412 -1.0894586 ]
# [ 5.85508688e-04  1.12291977e+00  6.22949512e-02 -1.35461768e+00]
# [ 0.0230439   0.92707372  0.0352026  -1.04311555]
# [ 0.04158538  0.73150242  0.01434029 -0.73959292]
# [ 5.62154268e-02  5.36185423e-01 -4.51571798e-04 -4.42431654e-01]
# [ 0.06693914  0.34106986 -0.0093002  -0.14989111]
# [ 0.07376053  0.53632375 -0.01229803 -0.44549349]
# [ 0.08448701  0.73161751 -0.0212079  -0.74202751]
# [ 0.09911936  0.53679464 -0.03604845 -0.45609357]
# [ 0.10985525  0.73240722 -0.04517032 -0.75991777]
# [ 0.12450339  0.53793577 -0.06036867 -0.4817837 ]
# [ 0.13526211  0.34371556 -0.07000435 -0.20872169]
# [ 0.14213642  0.53976504 -0.07417878 -0.52264011]
# [ 0.15293172  0.34576124 -0.08463158 -0.25422323]
# [ 0.15984695  0.54198323 -0.08971605 -0.57235475]
# [ 0.17068661  0.34822621 -0.10116314 -0.30922925]
# [ 0.17765114  0.54463312 -0.10734773 -0.63202464]
# [ 0.1885438   0.35115965 -0.11998822 -0.3749846 ]
# [ 0.19556699  0.1579282  -0.12748791 -0.12241336]
# [ 0.19872556 -0.03515861 -0.12993618  0.12748633]
# [ 0.19802238 -0.2282029  -0.12738645  0.37651794]
# [ 0.19345833 -0.03152358 -0.1198561   0.04653899]
# [ 0.19282785  0.16509493 -0.11892532 -0.2814263 ]
# [ 0.19612975  0.36169474 -0.12455384 -0.60912474]
# [ 0.20336365  0.16851384 -0.13673634 -0.35812242]
# [ 0.20673392  0.36528786 -0.14389878 -0.69060379]
# [ 0.21403968  0.17242474 -0.15771086 -0.44645951]
# [ 0.21748818  0.36938513 -0.16664005 -0.78440854]
# [ 0.22487588  0.17689698 -0.18232822 -0.54844167]
# [ 0.22841382 -0.01525864 -0.19329706 -0.31829393]
# [ 0.22810865 -0.20717776 -0.19966293 -0.09225274]
# [ 0.22396509 -0.39896136 -0.20150799  0.1313959 ]
# [ 0.21598586 -0.20160893 -0.19888007 -0.2174861 ]
# [ 0.21195368 -0.00428208 -0.20322979 -0.56572799]
# Episode finished after 47 timesteps
# [-0.00776395 -0.02325271 -0.00616767  0.01975024]
# [-0.00822901 -0.21828567 -0.00577266  0.31048083]
# [-0.01259472 -0.02308195  0.00043695  0.01598298]
# [-0.01305636 -0.21821016  0.00075661  0.30880374]
# [-0.01742056 -0.41334289  0.00693269  0.60172518]
# [-0.02568742 -0.21831859  0.01896719  0.31123397]
# [-0.03005379 -0.02347193  0.02519187  0.02459256]
# [-0.03052323  0.17127986  0.02568372 -0.2600368 ]
# [-0.02709763 -0.02419915  0.02048299  0.04063518]
# [-0.02758162  0.17062318  0.02129569 -0.24551544]
# [-0.02416915  0.36543461  0.01638538 -0.53140585]
# [-0.01686046  0.17008606  0.00575726 -0.23360528]
# [-0.01345874  0.36512528  0.00108516 -0.52446663]
# [-0.00615623  0.16998807 -0.00940418 -0.23144196]
# [-0.00275647  0.36524313 -0.01403301 -0.52707638]
# [ 0.00454839  0.56055969 -0.02457454 -0.82414795]
# [ 0.01575958  0.36578235 -0.0410575  -0.53929435]
# [ 0.02307523  0.1712609  -0.05184339 -0.25982558]
# [ 0.02650045  0.36708314 -0.0570399  -0.56839942]
# [ 0.03384211  0.5629568  -0.06840789 -0.87849272]
# [ 0.04510125  0.36882777 -0.08597774 -0.60807647]
# [ 0.0524778   0.56503985 -0.09813927 -0.92655377]
# [ 0.0637786   0.76134028 -0.11667035 -1.24839423]
# [ 0.07900541  0.95774859 -0.14163823 -1.57522715]
# [ 0.09816038  1.15424653 -0.17314277 -1.90852503]
# Episode finished after 25 timesteps
# [-0.01243396  0.01218939 -0.01581     0.01335228]
# [-0.01219017  0.20753447 -0.01554296 -0.28427666]
# [-0.00803948  0.01263761 -0.02122849  0.00346387]
# [-0.00778673 -0.18217356 -0.02115921  0.28937408]
# [-0.0114302   0.01324362 -0.01537173 -0.00990642]
# [-0.01116533 -0.18165454 -0.01556986  0.27788717]
# [-0.01479842  0.01368603 -0.01001212 -0.01966552]
# [-0.0145247  -0.18129091 -0.01040543  0.26984172]
# [-0.01815052 -0.37626284 -0.00500859  0.55922464]
# [-0.02567578 -0.18107095  0.0061759   0.26496795]
# [-0.02929719  0.01396231  0.01147526 -0.02576065]
# [-0.02901795  0.20891784  0.01096005 -0.31480103]
# [-0.02483959  0.40388196  0.00466403 -0.60400747]
# [-0.01676195  0.59893837 -0.00741612 -0.89521769]
# [-0.00478318  0.40391776 -0.02532048 -0.60487514]
# [ 0.00329517  0.59938449 -0.03741798 -0.90542466]
# [ 0.01528286  0.79499262 -0.05552647 -1.2096298 ]
# [ 0.03118271  0.99078591 -0.07971907 -1.5191835 ]
# [ 0.05099843  0.79671316 -0.11010274 -1.25241149]
# [ 0.06693269  0.60316036 -0.13515097 -0.99614513]
# [ 0.0789959   0.79980539 -0.15507387 -1.3280364 ]
# [ 0.09499201  0.99650673 -0.1816346  -1.66495703]
# Episode finished after 22 timesteps
# [-0.04749622 -0.0072057  -0.01644275 -0.0190672 ]
# [-0.04764033  0.18814815 -0.0168241  -0.31689232]
# [-0.04387737  0.38350564 -0.02316195 -0.61483314]
# [-0.03620726  0.57894344 -0.03545861 -0.91472021]
# [-0.02462839  0.38431855 -0.05375301 -0.63338902]
# [-0.01694202  0.18998603 -0.06642079 -0.35810704]
# [-0.0131423  -0.00413189 -0.07358293 -0.08708559]
# [-0.01322494  0.19196346 -0.07532465 -0.40204652]
# [-0.00938567 -0.0020138  -0.08336558 -0.1340302 ]
# [-0.00942594 -0.19584882 -0.08604618  0.13123148]
# [-0.01334292 -0.38963954 -0.08342155  0.39557574]
# [-0.02113571 -0.58348489 -0.07551004  0.6608351 ]
# [-0.03280541 -0.77747939 -0.06229333  0.9288188 ]
# [-0.048355   -0.97170759 -0.04371696  1.20129361]
# [-0.06778915 -0.77604834 -0.01969108  0.89523647]
# [-0.08331011 -0.580665   -0.00178636  0.59642947]
# [-0.09492341 -0.3855181   0.01014223  0.30318439]
# [-0.10263378 -0.58078312  0.01620592  0.59904862]
# [-0.11424944 -0.77612802  0.02818689  0.89679182]
# [-0.129772   -0.5813993   0.04612273  0.61310062]
# [-0.14139998 -0.38695121  0.05838474  0.33529395]
# [-0.14913901 -0.19270668  0.06509062  0.06157897]
# [-0.15299314 -0.38869857  0.0663222   0.37406739]
# [-0.16076711 -0.19457833  0.07380355  0.10301163]
# [-0.16465868 -0.39067612  0.07586378  0.41803611]
# [-0.1724722  -0.1967066   0.0842245   0.15020127]
# [-0.17640633 -0.39292729  0.08722853  0.4682217 ]
# [-0.18426488 -0.19913897  0.09659296  0.20425707]
# [-0.18824766 -0.00552155  0.1006781  -0.05646105]
# [-0.18835809  0.18802352  0.09954888 -0.31575917]
# [-0.18459762 -0.00836509  0.0932337   0.00658435]
# [-0.18476492  0.18530467  0.09336539 -0.25528758]
# [-0.18105883 -0.01101773  0.08825964  0.06532298]
# [-0.18127918 -0.20728694  0.0895661   0.38449554]
# [-0.18542492 -0.01354316  0.09725601  0.121342  ]
# [-0.18569579 -0.20991425  0.09968285  0.44305488]
# [-0.18989407 -0.01633367  0.10854394  0.18338371]
# [-0.19022074 -0.21282782  0.11221162  0.50823964]
# [-0.1944773  -0.40933706  0.12237641  0.83407073]
# [-0.20266404 -0.21608056  0.13905783  0.58224286]
# [-0.20698565 -0.41284874  0.15070268  0.91529739]
# [-0.21524263 -0.60965212  0.16900863  1.25129563]
# [-0.22743567 -0.80648757  0.19403454  1.59179437]
# Episode finished after 43 timesteps
# [-0.03623706  0.01087934 -0.02466869  0.02437632]
# [-0.03601947 -0.18388031 -0.02418116  0.30917505]
# [-0.03969707 -0.37864953 -0.01799766  0.5941349 ]
# [-0.04727007 -0.573515   -0.00611496  0.88109474]
# [-0.05874037 -0.76855336  0.01150693  1.17184902]
# [-0.07411143 -0.96382301  0.03494391  1.46811707]
# [-0.09338789 -0.76914572  0.06430626  1.18655083]
# [-0.10877081 -0.96503992  0.08803727  1.49867778]
# [-0.12807161 -0.77109108  0.11801083  1.23473074]
# [-0.14349343 -0.57766698  0.14270544  0.98122725]
# [-0.15504677 -0.77438312  0.16232999  1.31511514]
# [-0.17053443 -0.58164421  0.18863229  1.07732325]
# Episode finished after 12 timesteps
# [ 0.02972081 -0.01956561 -0.01921217  0.00072433]
# [ 0.0293295   0.17582653 -0.01919769 -0.29795782]
# [ 0.03284603 -0.01901657 -0.02515684 -0.01139079]
# [ 0.03246569 -0.21376888 -0.02538466  0.2732499 ]
# [ 0.02819032 -0.01829409 -0.01991966 -0.0273301 ]
# [ 0.02782443  0.17710777 -0.02046626 -0.32623074]
# [ 0.03136659  0.37251504 -0.02699088 -0.62529693]
# [ 0.03881689  0.56800318 -0.03949682 -0.92635668]
# [ 0.05017695  0.37343623 -0.05802395 -0.64634291]
# [ 0.05764568  0.56931662 -0.07095081 -0.95671849]
# [ 0.06903201  0.37521687 -0.09008518 -0.68714342]
# [ 0.07653635  0.57146613 -0.10382805 -1.00677289]
# [ 0.08796567  0.37787222 -0.1239635  -0.74841649]
# [ 0.09552312  0.1846585  -0.13893183 -0.49717189]
# [ 0.09921629 -0.00825918 -0.14887527 -0.25129834]
# [ 0.0990511  -0.20097635 -0.15390124 -0.00902801]
# [ 0.09503158 -0.00402059 -0.1540818  -0.34603836]
# [ 0.09495116  0.19291897 -0.16100257 -0.68306895]
# [ 0.09880954  0.38986692 -0.17466394 -1.02180073]
# [ 0.10660688  0.58683094 -0.19509996 -1.36384204]
# Episode finished after 20 timesteps
# [-0.01677484  0.02432472  0.04663795 -0.01630315]
# [-0.01628835 -0.17143397  0.04631189  0.29072219]
# [-0.01971703  0.02299807  0.05212633  0.01299765]
# [-0.01925707 -0.17283119  0.05238629  0.32166076]
# [-0.02271369  0.02150714  0.0588195   0.0459477 ]
# [-0.02228355 -0.17440677  0.05973845  0.35659331]
# [-0.02577168  0.01981724  0.06687032  0.08332965]
# [-0.02537534 -0.17619639  0.06853691  0.39633818]
# [-0.02889927  0.01788961  0.07646368  0.12602676]
# [-0.02854147  0.2118376   0.07898421 -0.14158676]
# [-0.02430472  0.01567851  0.07615248  0.17493178]
# [-0.02399115 -0.18044603  0.07965111  0.49063317]
# [-0.02760007 -0.37659592  0.08946378  0.80731785]
# [-0.03513199 -0.18280655  0.10561013  0.54406359]
# [-0.03878812  0.01068515  0.11649141  0.2864348 ]
# [-0.03857442  0.20396977  0.1222201   0.03264391]
# [-0.03449502  0.00732639  0.12287298  0.36125197]
# [-0.03434849 -0.18930831  0.13009802  0.6900141 ]
# [-0.03813466  0.00379129  0.1438983   0.44095348]
# [-0.03805884 -0.19304263  0.15271737  0.77531304]
# [-0.04191969 -0.38989832  0.16822363  1.11188446]
# [-0.04971765 -0.19733673  0.19046132  0.87634425]
# [-0.05366439 -0.39446581  0.20798821  1.22234854]
# Episode finished after 23 timesteps
# [-0.02061073 -0.03731566 -0.04775295 -0.04298771]
# [-0.02135704 -0.23172148 -0.04861271  0.23425457]
# [-0.02599147 -0.03593988 -0.04392762 -0.07335741]
# [-0.02671027 -0.23040544 -0.04539476  0.20514898]
# [-0.03131838 -0.03466472 -0.04129179 -0.10150112]
# [-0.03201167 -0.22917132 -0.04332181  0.17787376]
# [-0.0365951  -0.03345704 -0.03976433 -0.12815484]
# [-0.03726424 -0.22798746 -0.04232743  0.15172249]
# [-0.04182399 -0.03228578 -0.03929298 -0.15400765]
# [-0.04246971  0.1633761  -0.04237313 -0.4588231 ]
# [-0.03920218 -0.03112204 -0.05154959 -0.17979173]
# [-0.03982462 -0.22546988 -0.05514543  0.0961939 ]
# [-0.04433402 -0.0296027  -0.05322155 -0.2133648 ]
# [-0.04492608 -0.22392494 -0.05748885  0.0620661 ]
# [-0.04940457 -0.02802787 -0.05624753 -0.24818649]
# [-0.04996513 -0.2223033  -0.06121125  0.02623775]
# [-0.0544112  -0.02635937 -0.0606865  -0.28511256]
# [-0.05493839 -0.22056567 -0.06638875 -0.01217026]
# [-0.0593497  -0.4146758  -0.06663216  0.25884957]
# [-0.06764321 -0.60878636 -0.06145517  0.52979392]
# [-0.07981894 -0.80299239 -0.05085929  0.80249659]
# [-0.09587879 -0.60721127 -0.03480935  0.49425845]
# [-0.10802302 -0.41161613 -0.02492419  0.19081159]
# [-0.11625534 -0.60637281 -0.02110795  0.47552893]
# [-0.12838279 -0.41095926 -0.01159738  0.17626862]
# [-0.13660198 -0.60591334 -0.008072    0.46527052]
# [-0.14872025 -0.41067826  0.00123341  0.1700543 ]
# [-0.15693381 -0.21557399  0.00463449 -0.12223927]
# [-0.16124529 -0.41076203  0.00218971  0.17190219]
# [-0.16946053 -0.21567148  0.00562775 -0.12008915]
# [-0.17377396 -0.41087361  0.00322597  0.17436395]
# [-0.18199143 -0.60604158  0.00671325  0.46806282]
# [-0.19411227 -0.80125773  0.0160745   0.76285412]
# [-0.21013742 -0.99659736  0.03133159  1.06055141]
# [-0.23006937 -1.19211994  0.05254261  1.36290132]
# [-0.25391177 -0.9976942   0.07980064  1.08710561]
# [-0.27386565 -0.80371015  0.10154275  0.82049202]
# [-0.28993985 -1.00006417  0.11795259  1.14330821]
# [-0.30994114 -1.19651295  0.14081876  1.4705316 ]
# [-0.3338714  -1.39304846  0.17022939  1.80368075]
# [-0.36173236 -1.5896144   0.206303    2.14407396]
# Episode finished after 41 timesteps
# [-0.04536978  0.03551821 -0.04470009  0.02163654]
# [-0.04465941  0.23125175 -0.04426735 -0.28480796]
# [-0.04003438  0.03678819 -0.04996351 -0.00640873]
# [-0.03929861 -0.15758293 -0.05009169  0.27010095]
# [-0.04245027  0.03821673 -0.04468967 -0.03795093]
# [-0.04168594 -0.15623683 -0.04544869  0.24030379]
# [-0.04481067  0.0395039  -0.04064261 -0.06636143]
# [-0.04402059  0.23518428 -0.04196984 -0.37158524]
# [-0.03931691  0.43087657 -0.04940155 -0.6772007 ]
# [-0.03069938  0.62664883 -0.06294556 -0.98501898]
# [-0.0181664   0.82255487 -0.08264594 -1.29678984]
# [-0.0017153   1.01862349 -0.10858174 -1.61415919]
# [ 0.01865717  1.21484636 -0.14086492 -1.93862045]
# [ 0.04295409  1.41116396 -0.17963733 -2.27145749]
# Episode finished after 14 timesteps
# [-0.00639462  0.04705447 -0.03580825  0.0274912 ]
# [-0.00545353  0.24267115 -0.03525843 -0.2762711 ]
# [-0.00060011  0.43827793 -0.04078385 -0.57986274]
# [ 0.00816545  0.24375052 -0.0523811  -0.30030139]
# [ 0.01304046  0.04941279 -0.05838713 -0.02458762]
# [ 0.01402872  0.24532135 -0.05887888 -0.33510577]
# [ 0.01893514  0.44122968 -0.065581   -0.64575943]
# [ 0.02775974  0.63720122 -0.07849619 -0.95835183]
# [ 0.04050376  0.83328581 -0.09766322 -1.27462722]
# [ 0.05716948  0.63953584 -0.12315577 -1.01405453]
# [ 0.0699602   0.4462525  -0.14343686 -0.76244178]
# [ 0.07888525  0.64302817 -0.15868569 -1.0966001 ]
# [ 0.09174581  0.45031072 -0.1806177  -0.85761397]
# [ 0.10075202  0.25804819 -0.19776998 -0.62672485]
# Episode finished after 14 timesteps
# [-0.01123484 -0.00288948  0.00829154 -0.01265462]
# [-0.01129263 -0.19812936  0.00803845  0.28263281]
# [-0.01525522 -0.00312298  0.0136911  -0.00750403]
# [-0.01531768 -0.19843858  0.01354102  0.28946696]
# [-0.01928645 -0.00351231  0.01933036  0.00108531]
# [-0.01935669 -0.19890608  0.01935207  0.29980397]
# [-0.02333482 -0.39429845  0.02534815  0.5985268 ]
# [-0.03122079 -0.19954016  0.03731868  0.31393478]
# [-0.03521159 -0.39517331  0.04359738  0.61814933]
# [-0.04311505 -0.59087627  0.05596036  0.9242384 ]
# [-0.05493258 -0.78670766  0.07444513  1.23396942]
# [-0.07066673 -0.9827035   0.09912452  1.54901555]
# [-0.0903208  -1.17886552  0.13010483  1.8709091 ]
# [-0.11389811 -0.98538372  0.16752301  1.62128228]
# [-0.13360579 -1.18203585  0.19994866  1.96115273]
# Episode finished after 15 timesteps
# [ 0.0135669   0.02252433 -0.00752175  0.02007765]
# [ 0.01401739 -0.17248895 -0.0071202   0.31037792]
# [ 0.01056761 -0.36750873 -0.00091264  0.60080687]
# [ 0.00321744 -0.17237403  0.0111035   0.30783661]
# [-0.00023004  0.02258796  0.01726023  0.01867601]
# [ 2.21714724e-04  2.17458186e-01  1.76337476e-02 -2.68511527e-01]
# [ 0.00457088  0.4123241   0.01226352 -0.55558091]
# [ 0.01281736  0.21703213  0.0011519  -0.2590596 ]
# [ 0.017158    0.02189376 -0.00402929  0.03398643]
# [ 0.01759588  0.21707326 -0.00334956 -0.25996505]
# [ 0.02193734  0.02199928 -0.00854887  0.0316595 ]
# [ 0.02237733  0.21724278 -0.00791568 -0.26370838]
# [ 0.02672218  0.41247682 -0.01318984 -0.55887744]
# [ 0.03497172  0.6077814  -0.02436739 -0.85568654]
# [ 0.04712735  0.80322678 -0.04148112 -1.15593089]
# [ 0.06319188  0.60866947 -0.06459974 -0.87653791]
# [ 0.07536527  0.41448223 -0.0821305  -0.60484372]
# [ 0.08365492  0.61065087 -0.09422737 -0.92222405]
# [ 0.09586794  0.41691972 -0.11267185 -0.66057831]
# [ 0.10420633  0.22353102 -0.12588342 -0.40539009]
# [ 0.10867695  0.42019235 -0.13399122 -0.73495991]
# [ 0.1170808   0.61688576 -0.14869042 -1.06663112]
# [ 0.12941851  0.81362849 -0.17002304 -1.40204298]
# [ 0.14569108  0.62097729 -0.1980639  -1.16697926]
# Episode finished after 24 timesteps
# [-0.0329458   0.04963472 -0.02457102 -0.03189178]
# [-0.03195311 -0.14512641 -0.02520885  0.25293858]
# [-0.03485564  0.05034626 -0.02015008 -0.04758788]
# [-0.03384871  0.24575126 -0.02110184 -0.34655961]
# [-0.02893369  0.05093573 -0.02803303 -0.06060485]
# [-0.02791497  0.24644816 -0.02924513 -0.36199891]
# [-0.02298601  0.05175383 -0.03648511 -0.07867914]
# [-0.02195093 -0.14282661 -0.03805869  0.20227304]
# [-0.02480746 -0.33738418 -0.03401323  0.48271151]
# [-0.03155515 -0.14179908 -0.024359    0.1795056 ]
# [-0.03439113  0.05366282 -0.02076889 -0.12076112]
# [-0.03331787 -0.1411555  -0.02318411  0.16529773]
# [-0.03614098  0.05429052 -0.01987815 -0.13460803]
# [-0.03505517 -0.14054114 -0.02257032  0.15173793]
# [-0.037866    0.0548966  -0.01953556 -0.14797912]
# [-0.03676806 -0.13994023 -0.02249514  0.13847727]
# [-0.03956687 -0.33473289 -0.01972559  0.42397932]
# [-0.04626153 -0.13933714 -0.01124601  0.12514376]
# [-0.04904827 -0.33429619 -0.00874313  0.41425758]
# [-5.57341928e-02 -5.29293130e-01 -4.57980731e-04  7.04171369e-01]
# [-0.06632006 -0.72440873  0.01362545  0.99671009]
# [-0.08080823 -0.91971021  0.03355965  1.29364087]
# [-0.09920243 -1.1152422   0.05943247  1.5966384 ]
# [-0.12150728 -0.92087305  0.09136523  1.32306229]
# [-0.13992474 -0.72701639  0.11782648  1.06031416]
# [-0.15446507 -0.53363524  0.13903276  0.80681455]
# [-0.16513777 -0.3406648   0.15516905  0.56089605]
# [-0.17195107 -0.14802189  0.16638698  0.32084033]
# [-0.17491151  0.04438808  0.17280378  0.08490364]
# [-0.17402374  0.23666606  0.17450185 -0.14866597]
# [-0.16929042  0.42891562  0.17152854 -0.38161724]
# [-0.16071211  0.23182607  0.16389619 -0.04013888]
# [-0.15607559  0.03477958  0.16309341  0.29943999]
# [-0.15538    -0.16224583  0.16908221  0.6387934 ]
# [-0.15862491 -0.35927148  0.18185808  0.97959105]
# [-0.16581034 -0.1669914   0.2014499   0.74909921]
# Episode finished after 36 timesteps
# [ 0.03170887 -0.00703106  0.04177759 -0.02900421]
# [ 0.03156824  0.18746764  0.04119751 -0.30821866]
# [ 0.0353176   0.38197911  0.03503313 -0.58762965]
# [ 0.04295718  0.1863845   0.02328054 -0.28412013]
# [ 0.04668487  0.3811668   0.01759814 -0.56937055]
# [ 0.05430821  0.18580251  0.00621073 -0.27119591]
# [ 0.05802426 -0.00940751  0.00078681  0.02343942]
# [ 0.05783611  0.18570315  0.0012556  -0.26899515]
# [ 0.06155017  0.38080716 -0.00412431 -0.56128179]
# [ 0.06916631  0.57598675 -0.01534994 -0.85526123]
# [ 0.08068605  0.38107731 -0.03245517 -0.56744422]
# [ 0.08830759  0.57663912 -0.04380405 -0.87017261]
# [ 0.09984038  0.77232868 -0.0612075  -1.17629964]
# [ 0.11528695  0.96819005 -0.0847335  -1.48752531]
# [ 0.13465075  0.77419646 -0.114484   -1.22246078]
# [ 0.15013468  0.9705919  -0.13893322 -1.5487103 ]
# [ 0.16954652  1.16708102 -0.16990742 -1.88131911]
# [ 0.19288814  1.36359806 -0.20753381 -2.22156281]
# Episode finished after 18 timesteps
# [ 0.04190691 -0.007719    0.00421651 -0.00882385]
# [ 0.04175253  0.18734223  0.00404003 -0.30017344]
# [ 0.04549937 -0.00783707 -0.00196344 -0.00621911]
# [ 0.04534263 -0.20293081 -0.00208782  0.28584368]
# [ 0.04128401 -0.00777914  0.00362906 -0.007497  ]
# [ 0.04112843 -0.20295295  0.00347912  0.28632873]
# [ 0.03706937 -0.39812435  0.00920569  0.58010691]
# [ 0.02910688 -0.59337408  0.02080783  0.87567553]
# [ 0.0172394  -0.39854107  0.03832134  0.58960633]
# [ 0.00926858 -0.59417806  0.05011347  0.89411009]
# [-0.00261498 -0.39977023  0.06799567  0.61759164]
# [-0.01061039 -0.59577285  0.0803475   0.9308915 ]
# [-0.02252584 -0.40182181  0.09896533  0.66450026]
# [-0.03056228 -0.598171    0.11225534  0.98663126]
# [-0.0425257  -0.40471671  0.13198796  0.73121003]
# [-0.05062003 -0.21164178  0.14661216  0.48280852]
# [-0.05485287 -0.40849574  0.15626833  0.8178713 ]
# [-0.06302278 -0.21581852  0.17262576  0.57813328]
# [-0.06733915 -0.41288583  0.18418842  0.91984105]
# [-0.07559687 -0.6099551   0.20258524  1.26429061]
# Episode finished after 20 timesteps
# [ 0.00956188 -0.03201937  0.01062736 -0.0262198 ]
# [ 0.00892149  0.16294857  0.01010296 -0.31553082]
# [ 0.01218046 -0.03231582  0.00379235 -0.01967896]
# [ 0.01153414  0.16275154  0.00339877 -0.31116295]
# [ 0.01478917 -0.03241867 -0.00282449 -0.01741009]
# [ 0.0141408   0.16274368 -0.00317269 -0.31098284]
# [ 0.01739567  0.35791069 -0.00939235 -0.60466465]
# [ 0.02455389  0.16292133 -0.02148564 -0.31495483]
# [ 0.02781231  0.35834265 -0.02778474 -0.61433544]
# [ 0.03497917  0.5538416  -0.04007145 -0.91563834]
# [ 0.046056    0.35928379 -0.05838421 -0.63581376]
# [ 0.05324168  0.55516934 -0.07110049 -0.94629665]
# [ 0.06434506  0.7511731  -0.09002642 -1.2604454 ]
# [ 0.07936852  0.94732384 -0.11523533 -1.57991202]
# [ 0.098315    1.14361396 -0.14683357 -1.90619869]
# [ 0.12118728  1.33998536 -0.18495754 -2.24060026]
# Episode finished after 16 timesteps

# %% [markdown]
# ### Spaces
#
# In the examples above, we’ve been sampling random actions from the environment’s action space. But what actually are those actions? Every environment comes with an `action_space` and an `observation_space`. These attributes are of type `Space`, and they describe the format of valid actions and observations:

# %%
import gym
import gym.spaces

env = gym.make('CartPole-v0')
print(env.action_space)
#> Discrete(2)
print(env.observation_space)
#> Box(4,)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Discrete(2)
# Box(4,)
# /Users/jayurbain/Dropbox/Reinforcement Learning/gym/gym/__init__.py:22: UserWarning: DEPRECATION WARNING: to improve load times, gym no longer automatically loads gym.spaces. Please run "import gym.spaces" to load gym.spaces on your own. This warning will turn into an error in a future version of gym.
#   warnings.warn('DEPRECATION WARNING: to improve load times, gym no longer automatically loads gym.spaces. Please run "import gym.spaces" to load gym.spaces on your own. This warning will turn into an error in a future version of gym.')

# %% [markdown]
# The Discrete space allows a fixed range of non-negative numbers, so in this case valid actions are either 0 or 1. The Box space represents an n-dimensional box, so valid observations will be an array of 4 numbers. We can also check the Box’s bounds:

# %%
print(env.observation_space.high)
#> array([ 2.4       ,         inf,  0.20943951,         inf])
print(env.observation_space.low)
#> array([-2.4       ,        -inf, -0.20943951,        -inf])
# Out:
# [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38]
# [-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38]

# %% [markdown]
# This introspection can be helpful to write generic code that works for many different environments. Box and Discrete are the most common Spaces. You can sample from a Space or check that something belongs to it:

# %%
from gym import spaces
space = spaces.Discrete(8) # Set with 8 elements {0, 1, 2, ..., 7}
x = space.sample()
assert space.contains(x)
assert space.n == 8

# %% [markdown]
# For CartPole-v0 one of the actions applies force to the left, and one of them applies force to the right. (Can you figure out which is which?)
#
# Fortunately, the better your learning algorithm, the less you’ll have to try to interpret these numbers yourself.

# %% [markdown]
# ### Deep Reinforcement Learning
#
# Google’s DeepMind published its famous paper [Playing Atari with Deep Reinforcement Learning](https://arxiv.org/abs/1312.5602), in which they introduced a new algorithm called Deep Q Network (DQN for short) in 2013. It demonstrated how an AI agent can learn to play games by just observing the screen without any prior information about those games. The result turned out to be pretty impressive. This paper opened the era of what is called ‘deep reinforcement learning’, a mix of deep learning and reinforcement learning.
#
# [Click to Watch: DeepMind’s Atari Player](https://www.youtube.com/watch?v=V1eYniJ0Rnk)
#
# <img src='images/atari.png' width=400px></img>
#
# In Q-Learning Algorithm, there is a function called Q Function, which is used to approximate the reward based on a state. We call it Q(s,a), where Q is a function which calculates the expected future value from state s and action a. Similarly in Deep Q Network algorithm, we use a neural network to approximate the reward based on the state. We will discuss how this works in detail.

# %% [markdown]
# ### Implementing a MLP  using Keras
#
# For this tutorial, we can treat the neural network as a black box algorithm that maps inputs to outputs. It is  an algorithm that learns on the pairs of examples input and output data, detects some kind of patterns, and predicts the output based on an unseen input data. It's important to understand how the neural network is used in the DQN algorithm.
#
# <img src='images/neuralnet.png' width='500px'></img>
#
# Note that the neural net we are going to use is similar to the diagram above. We will have one input layer that receives 4 information and 3 hidden layers. But we are going to have 2 nodes in the output layer since there are two buttons (0 and 1) for the game.
#
# Keras makes it really simple to implement a basic neural network. The code below creates an empty neural net model. activation, loss and optimizer are the parameters that define the characteristics of the neural network, but we are not going to discuss it here.

# %% [markdown]
# #### Imports

# %%
import random
import gym
import numpy as np
from collections import deque
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.
# /Applications/anaconda/envs/py3.6tf1.3keras/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# #### Keras neural network model for Q-Learning

# %%
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95    # discount rate
        self.epsilon = 1.0  # exploration rate
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.model = self._build_model()

    def _build_model(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()
        model.add(Dense(24, input_dim=self.state_size, activation='relu'))
        model.add(Dense(24, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss='mse',
                      optimizer=Adam(lr=self.learning_rate))
        return model

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])  # returns action

    def replay(self, batch_size):
        minibatch = random.sample(self.memory, batch_size)
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = (reward + self.gamma *
                          np.amax(self.model.predict(next_state)[0]))
            target_f = self.model.predict(state)
            target_f[0][action] = target
            self.model.fit(state, target_f, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def load(self, name):
        self.model.load_weights(name)

    def save(self, name):
        self.model.save_weights(name)

# %% [markdown]
# #### Make OpenAI environment

# %%
# %matplotlib inline

EPISODES = 1000

env = gym.make('CartPole-v1')
state_size = env.observation_space.shape[0]
action_size = env.action_space.n
agent = DQNAgent(state_size, action_size)
# agent.load("./save/cartpole-dqn.h5")
done = False
batch_size = 32

for e in range(EPISODES):
    state = env.reset()
    state = np.reshape(state, [1, state_size])
    for time in range(500):
        env.render()
        action = agent.act(state)
        next_state, reward, done, _ = env.step(action)
        reward = reward if not done else -10
        next_state = np.reshape(next_state, [1, state_size])
        agent.remember(state, action, reward, next_state, done)
        state = next_state
        if done:
            print("episode: {}/{}, score: {}, e: {:.2}"
                    .format(e, EPISODES, time, agent.epsilon))
            break
        if len(agent.memory) > batch_size:
            agent.replay(batch_size)
    # if e % 10 == 0:
    #     agent.save("./save/cartpole-dqn.h5")
# Out:
# /Users/jayurbain/Dropbox/Reinforcement Learning/gym/gym/__init__.py:22: UserWarning: DEPRECATION WARNING: to improve load times, gym no longer automatically loads gym.spaces. Please run "import gym.spaces" to load gym.spaces on your own. This warning will turn into an error in a future version of gym.
#   warnings.warn('DEPRECATION WARNING: to improve load times, gym no longer automatically loads gym.spaces. Please run "import gym.spaces" to load gym.spaces on your own. This warning will turn into an error in a future version of gym.')
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# episode: 0/1000, score: 14, e: 1.0
# episode: 1/1000, score: 28, e: 0.95
# episode: 2/1000, score: 26, e: 0.83
# episode: 3/1000, score: 20, e: 0.75
# episode: 4/1000, score: 14, e: 0.7
# episode: 5/1000, score: 15, e: 0.65
# episode: 6/1000, score: 10, e: 0.62
# episode: 7/1000, score: 18, e: 0.56
# episode: 8/1000, score: 8, e: 0.54
# episode: 9/1000, score: 11, e: 0.51
# episode: 10/1000, score: 8, e: 0.49
# episode: 11/1000, score: 7, e: 0.48
# episode: 12/1000, score: 12, e: 0.45
# episode: 13/1000, score: 8, e: 0.43
# episode: 14/1000, score: 17, e: 0.4
# episode: 15/1000, score: 11, e: 0.37
# episode: 16/1000, score: 13, e: 0.35
# episode: 17/1000, score: 16, e: 0.32
# episode: 18/1000, score: 29, e: 0.28
# episode: 19/1000, score: 42, e: 0.23
# episode: 20/1000, score: 46, e: 0.18
# episode: 21/1000, score: 68, e: 0.13
# episode: 22/1000, score: 33, e: 0.11
# episode: 23/1000, score: 34, e: 0.092
# episode: 24/1000, score: 33, e: 0.078
# episode: 25/1000, score: 47, e: 0.061
# episode: 26/1000, score: 322, e: 0.012
# episode: 27/1000, score: 291, e: 0.01
# episode: 28/1000, score: 239, e: 0.01
# episode: 29/1000, score: 183, e: 0.01
# episode: 30/1000, score: 160, e: 0.01
# episode: 31/1000, score: 170, e: 0.01
# episode: 32/1000, score: 176, e: 0.01
# episode: 33/1000, score: 129, e: 0.01
# episode: 34/1000, score: 200, e: 0.01
# episode: 35/1000, score: 158, e: 0.01
# episode: 36/1000, score: 180, e: 0.01
# episode: 37/1000, score: 131, e: 0.01
# episode: 38/1000, score: 18, e: 0.01
# episode: 39/1000, score: 8, e: 0.01
# episode: 40/1000, score: 121, e: 0.01
# episode: 41/1000, score: 201, e: 0.01
# episode: 42/1000, score: 60, e: 0.01
# episode: 43/1000, score: 72, e: 0.01
# episode: 44/1000, score: 101, e: 0.01
# episode: 45/1000, score: 164, e: 0.01
# episode: 46/1000, score: 142, e: 0.01
# episode: 47/1000, score: 179, e: 0.01
# episode: 48/1000, score: 220, e: 0.01
# episode: 49/1000, score: 215, e: 0.01
# episode: 50/1000, score: 150, e: 0.01
# episode: 51/1000, score: 179, e: 0.01
# episode: 52/1000, score: 170, e: 0.01
# episode: 53/1000, score: 166, e: 0.01
# episode: 54/1000, score: 170, e: 0.01
# episode: 55/1000, score: 162, e: 0.01
# episode: 56/1000, score: 152, e: 0.01
# episode: 57/1000, score: 19, e: 0.01
# episode: 58/1000, score: 140, e: 0.01
# episode: 59/1000, score: 202, e: 0.01
# episode: 60/1000, score: 217, e: 0.01
# episode: 61/1000, score: 114, e: 0.01
# episode: 62/1000, score: 82, e: 0.01
# episode: 63/1000, score: 37, e: 0.01
# episode: 64/1000, score: 36, e: 0.01
# episode: 65/1000, score: 30, e: 0.01
# episode: 66/1000, score: 19, e: 0.01
# episode: 67/1000, score: 329, e: 0.01
# episode: 68/1000, score: 183, e: 0.01
# episode: 69/1000, score: 171, e: 0.01
# episode: 70/1000, score: 191, e: 0.01
# episode: 71/1000, score: 166, e: 0.01
# episode: 72/1000, score: 142, e: 0.01
# episode: 73/1000, score: 140, e: 0.01
# episode: 74/1000, score: 150, e: 0.01
# episode: 75/1000, score: 124, e: 0.01
# episode: 76/1000, score: 10, e: 0.01
# episode: 77/1000, score: 205, e: 0.01
# episode: 78/1000, score: 173, e: 0.01
# episode: 79/1000, score: 190, e: 0.01
# episode: 80/1000, score: 158, e: 0.01
# episode: 81/1000, score: 26, e: 0.01
# episode: 82/1000, score: 163, e: 0.01
# episode: 83/1000, score: 145, e: 0.01
# episode: 84/1000, score: 132, e: 0.01
# episode: 85/1000, score: 168, e: 0.01
# episode: 86/1000, score: 152, e: 0.01
# episode: 87/1000, score: 134, e: 0.01
# episode: 88/1000, score: 148, e: 0.01
# episode: 89/1000, score: 166, e: 0.01
# episode: 90/1000, score: 163, e: 0.01
# episode: 91/1000, score: 153, e: 0.01
# episode: 92/1000, score: 147, e: 0.01
# episode: 93/1000, score: 143, e: 0.01
# episode: 94/1000, score: 152, e: 0.01
# episode: 95/1000, score: 72, e: 0.01
# episode: 96/1000, score: 276, e: 0.01
# episode: 97/1000, score: 23, e: 0.01
# episode: 98/1000, score: 170, e: 0.01
# episode: 99/1000, score: 254, e: 0.01
# episode: 100/1000, score: 189, e: 0.01
# episode: 101/1000, score: 260, e: 0.01
# episode: 102/1000, score: 182, e: 0.01
# episode: 103/1000, score: 187, e: 0.01
# episode: 104/1000, score: 499, e: 0.01
# episode: 105/1000, score: 392, e: 0.01
# episode: 106/1000, score: 144, e: 0.01
# episode: 107/1000, score: 499, e: 0.01
# episode: 108/1000, score: 210, e: 0.01
# episode: 109/1000, score: 499, e: 0.01
# episode: 110/1000, score: 195, e: 0.01
# episode: 111/1000, score: 57, e: 0.01
# episode: 112/1000, score: 38, e: 0.01
# episode: 113/1000, score: 308, e: 0.01
# episode: 114/1000, score: 183, e: 0.01
# episode: 115/1000, score: 266, e: 0.01
# episode: 116/1000, score: 267, e: 0.01
# episode: 117/1000, score: 361, e: 0.01
# episode: 118/1000, score: 414, e: 0.01
# episode: 119/1000, score: 410, e: 0.01
# episode: 120/1000, score: 117, e: 0.01
# episode: 121/1000, score: 32, e: 0.01
# episode: 122/1000, score: 120, e: 0.01
# episode: 123/1000, score: 114, e: 0.01
# episode: 124/1000, score: 135, e: 0.01
# episode: 125/1000, score: 172, e: 0.01
# episode: 126/1000, score: 177, e: 0.01
# episode: 127/1000, score: 144, e: 0.01
# episode: 128/1000, score: 79, e: 0.01
# episode: 129/1000, score: 14, e: 0.01
# episode: 130/1000, score: 11, e: 0.01
# episode: 131/1000, score: 196, e: 0.01
# episode: 132/1000, score: 357, e: 0.01
# episode: 133/1000, score: 196, e: 0.01
# episode: 134/1000, score: 253, e: 0.01
# episode: 135/1000, score: 167, e: 0.01
# episode: 136/1000, score: 290, e: 0.01
# episode: 137/1000, score: 113, e: 0.01
# episode: 138/1000, score: 163, e: 0.01
# episode: 139/1000, score: 180, e: 0.01
# episode: 140/1000, score: 212, e: 0.01
# episode: 141/1000, score: 96, e: 0.01
# episode: 142/1000, score: 99, e: 0.01
# episode: 143/1000, score: 170, e: 0.01
# episode: 144/1000, score: 240, e: 0.01
# episode: 145/1000, score: 195, e: 0.01
# episode: 146/1000, score: 228, e: 0.01
# episode: 147/1000, score: 147, e: 0.01
# episode: 148/1000, score: 132, e: 0.01
# episode: 149/1000, score: 194, e: 0.01
# episode: 150/1000, score: 170, e: 0.01
# episode: 151/1000, score: 153, e: 0.01
# episode: 152/1000, score: 164, e: 0.01
# episode: 153/1000, score: 219, e: 0.01
# episode: 154/1000, score: 147, e: 0.01
# episode: 155/1000, score: 129, e: 0.01
# episode: 156/1000, score: 117, e: 0.01
# episode: 157/1000, score: 140, e: 0.01
# episode: 158/1000, score: 145, e: 0.01
# episode: 159/1000, score: 128, e: 0.01
# episode: 160/1000, score: 182, e: 0.01
# episode: 161/1000, score: 53, e: 0.01
# episode: 162/1000, score: 137, e: 0.01
# episode: 163/1000, score: 148, e: 0.01
# episode: 164/1000, score: 118, e: 0.01
# episode: 165/1000, score: 185, e: 0.01
# episode: 166/1000, score: 115, e: 0.01
# episode: 167/1000, score: 98, e: 0.01
# episode: 168/1000, score: 118, e: 0.01
# episode: 169/1000, score: 152, e: 0.01
# episode: 170/1000, score: 14, e: 0.01
# episode: 171/1000, score: 15, e: 0.01
# episode: 172/1000, score: 14, e: 0.01
# episode: 173/1000, score: 11, e: 0.01
# episode: 174/1000, score: 16, e: 0.01
# episode: 175/1000, score: 216, e: 0.01
# episode: 176/1000, score: 250, e: 0.01
# episode: 177/1000, score: 270, e: 0.01
# episode: 178/1000, score: 176, e: 0.01
# episode: 179/1000, score: 161, e: 0.01
# episode: 180/1000, score: 161, e: 0.01
# episode: 181/1000, score: 189, e: 0.01
# episode: 182/1000, score: 180, e: 0.01
# episode: 183/1000, score: 162, e: 0.01
# episode: 184/1000, score: 156, e: 0.01
# episode: 185/1000, score: 140, e: 0.01
# episode: 186/1000, score: 172, e: 0.01
# episode: 187/1000, score: 186, e: 0.01
# episode: 188/1000, score: 153, e: 0.01
# episode: 189/1000, score: 166, e: 0.01
# episode: 190/1000, score: 109, e: 0.01
# episode: 191/1000, score: 150, e: 0.01
# episode: 192/1000, score: 156, e: 0.01
# episode: 193/1000, score: 78, e: 0.01
# episode: 194/1000, score: 140, e: 0.01
# episode: 195/1000, score: 185, e: 0.01
# episode: 196/1000, score: 149, e: 0.01
# episode: 197/1000, score: 187, e: 0.01
# episode: 198/1000, score: 132, e: 0.01
# episode: 199/1000, score: 158, e: 0.01
# episode: 200/1000, score: 247, e: 0.01
# episode: 201/1000, score: 131, e: 0.01
# episode: 202/1000, score: 149, e: 0.01
# episode: 203/1000, score: 130, e: 0.01
# episode: 204/1000, score: 161, e: 0.01
# episode: 205/1000, score: 156, e: 0.01
# episode: 206/1000, score: 177, e: 0.01
# episode: 207/1000, score: 210, e: 0.01
# episode: 208/1000, score: 163, e: 0.01
# episode: 209/1000, score: 24, e: 0.01
# episode: 210/1000, score: 46, e: 0.01
# episode: 211/1000, score: 120, e: 0.01
# episode: 212/1000, score: 206, e: 0.01
# episode: 213/1000, score: 171, e: 0.01
# episode: 214/1000, score: 196, e: 0.01
# episode: 215/1000, score: 130, e: 0.01
# episode: 216/1000, score: 148, e: 0.01
# episode: 217/1000, score: 166, e: 0.01
# episode: 218/1000, score: 134, e: 0.01
# episode: 219/1000, score: 116, e: 0.01
# episode: 220/1000, score: 126, e: 0.01
# episode: 221/1000, score: 135, e: 0.01
# episode: 222/1000, score: 146, e: 0.01
# episode: 223/1000, score: 141, e: 0.01
# episode: 224/1000, score: 152, e: 0.01
# episode: 225/1000, score: 163, e: 0.01
# episode: 226/1000, score: 177, e: 0.01
# episode: 227/1000, score: 146, e: 0.01
# episode: 228/1000, score: 153, e: 0.01
# episode: 229/1000, score: 226, e: 0.01
# episode: 230/1000, score: 151, e: 0.01
# episode: 231/1000, score: 98, e: 0.01
# episode: 232/1000, score: 43, e: 0.01
# episode: 233/1000, score: 12, e: 0.01
# episode: 234/1000, score: 135, e: 0.01
# episode: 235/1000, score: 202, e: 0.01
# episode: 236/1000, score: 124, e: 0.01
# episode: 237/1000, score: 160, e: 0.01
# episode: 238/1000, score: 44, e: 0.01
# episode: 239/1000, score: 135, e: 0.01
# episode: 240/1000, score: 117, e: 0.01
# episode: 241/1000, score: 108, e: 0.01
# episode: 242/1000, score: 118, e: 0.01
# episode: 243/1000, score: 98, e: 0.01
# episode: 244/1000, score: 124, e: 0.01
# episode: 245/1000, score: 110, e: 0.01
# episode: 246/1000, score: 129, e: 0.01
# episode: 247/1000, score: 152, e: 0.01
# episode: 248/1000, score: 104, e: 0.01
# episode: 249/1000, score: 158, e: 0.01
# episode: 250/1000, score: 141, e: 0.01
# episode: 251/1000, score: 173, e: 0.01
# episode: 252/1000, score: 77, e: 0.01
# episode: 253/1000, score: 8, e: 0.01
# episode: 254/1000, score: 7, e: 0.01
# episode: 255/1000, score: 8, e: 0.01
# episode: 256/1000, score: 9, e: 0.01
# episode: 257/1000, score: 7, e: 0.01
# episode: 258/1000, score: 8, e: 0.01
# episode: 259/1000, score: 11, e: 0.01
# episode: 260/1000, score: 20, e: 0.01
# episode: 261/1000, score: 101, e: 0.01
# episode: 262/1000, score: 96, e: 0.01
# episode: 263/1000, score: 47, e: 0.01
# episode: 264/1000, score: 9, e: 0.01
# episode: 265/1000, score: 173, e: 0.01
# episode: 266/1000, score: 137, e: 0.01
# episode: 267/1000, score: 119, e: 0.01
# episode: 268/1000, score: 157, e: 0.01
# episode: 269/1000, score: 121, e: 0.01
# episode: 270/1000, score: 128, e: 0.01
# episode: 271/1000, score: 127, e: 0.01
# episode: 272/1000, score: 136, e: 0.01
# episode: 273/1000, score: 127, e: 0.01
# episode: 274/1000, score: 153, e: 0.01
# episode: 275/1000, score: 121, e: 0.01
# episode: 276/1000, score: 144, e: 0.01
# episode: 277/1000, score: 114, e: 0.01
# episode: 278/1000, score: 142, e: 0.01
# episode: 279/1000, score: 129, e: 0.01
# episode: 280/1000, score: 129, e: 0.01
# episode: 281/1000, score: 135, e: 0.01
# episode: 282/1000, score: 126, e: 0.01
# episode: 283/1000, score: 124, e: 0.01
# episode: 284/1000, score: 235, e: 0.01
# episode: 285/1000, score: 145, e: 0.01
# episode: 286/1000, score: 204, e: 0.01
# episode: 287/1000, score: 128, e: 0.01
# episode: 288/1000, score: 252, e: 0.01
# episode: 289/1000, score: 164, e: 0.01
# episode: 290/1000, score: 144, e: 0.01
# episode: 291/1000, score: 147, e: 0.01
# episode: 292/1000, score: 150, e: 0.01
# episode: 293/1000, score: 262, e: 0.01
# episode: 294/1000, score: 196, e: 0.01
# episode: 295/1000, score: 125, e: 0.01
# episode: 296/1000, score: 215, e: 0.01
# episode: 297/1000, score: 277, e: 0.01
# episode: 298/1000, score: 137, e: 0.01
# episode: 299/1000, score: 175, e: 0.01
# episode: 300/1000, score: 246, e: 0.01
# episode: 301/1000, score: 169, e: 0.01
# episode: 302/1000, score: 29, e: 0.01
# episode: 303/1000, score: 119, e: 0.01
# episode: 304/1000, score: 11, e: 0.01
# episode: 305/1000, score: 201, e: 0.01
# episode: 306/1000, score: 307, e: 0.01
# episode: 307/1000, score: 61, e: 0.01
# episode: 308/1000, score: 126, e: 0.01
# episode: 309/1000, score: 144, e: 0.01
# episode: 310/1000, score: 156, e: 0.01
# episode: 311/1000, score: 172, e: 0.01
# episode: 312/1000, score: 129, e: 0.01
# episode: 313/1000, score: 139, e: 0.01
# episode: 314/1000, score: 209, e: 0.01
# episode: 315/1000, score: 132, e: 0.01
# episode: 316/1000, score: 154, e: 0.01
# episode: 317/1000, score: 138, e: 0.01
# episode: 318/1000, score: 211, e: 0.01
# episode: 319/1000, score: 226, e: 0.01
# episode: 320/1000, score: 10, e: 0.01
# episode: 321/1000, score: 10, e: 0.01
# episode: 322/1000, score: 9, e: 0.01
# episode: 323/1000, score: 7, e: 0.01
# episode: 324/1000, score: 9, e: 0.01
# episode: 325/1000, score: 121, e: 0.01
# episode: 326/1000, score: 102, e: 0.01
# episode: 327/1000, score: 22, e: 0.01
# episode: 328/1000, score: 36, e: 0.01
# episode: 329/1000, score: 162, e: 0.01
# episode: 330/1000, score: 191, e: 0.01
# episode: 331/1000, score: 277, e: 0.01
# episode: 332/1000, score: 267, e: 0.01
# episode: 333/1000, score: 157, e: 0.01
# episode: 334/1000, score: 118, e: 0.01
# episode: 335/1000, score: 119, e: 0.01
# episode: 336/1000, score: 207, e: 0.01
# episode: 337/1000, score: 235, e: 0.01
# episode: 338/1000, score: 101, e: 0.01
# episode: 339/1000, score: 332, e: 0.01
# episode: 340/1000, score: 139, e: 0.01
# episode: 341/1000, score: 76, e: 0.01
# episode: 342/1000, score: 17, e: 0.01
# episode: 343/1000, score: 117, e: 0.01
# episode: 344/1000, score: 156, e: 0.01
# episode: 345/1000, score: 34, e: 0.01
# episode: 346/1000, score: 55, e: 0.01
# episode: 347/1000, score: 147, e: 0.01
# episode: 348/1000, score: 499, e: 0.01
# episode: 349/1000, score: 499, e: 0.01
# episode: 350/1000, score: 82, e: 0.01
# episode: 351/1000, score: 461, e: 0.01
# episode: 352/1000, score: 399, e: 0.01
# episode: 353/1000, score: 21, e: 0.01
# episode: 354/1000, score: 12, e: 0.01
# episode: 355/1000, score: 9, e: 0.01
# episode: 356/1000, score: 9, e: 0.01
# episode: 357/1000, score: 9, e: 0.01
# episode: 358/1000, score: 8, e: 0.01
# episode: 359/1000, score: 8, e: 0.01
# episode: 360/1000, score: 9, e: 0.01
# episode: 361/1000, score: 8, e: 0.01
# episode: 362/1000, score: 8, e: 0.01
# episode: 363/1000, score: 8, e: 0.01
# episode: 364/1000, score: 9, e: 0.01
# episode: 365/1000, score: 9, e: 0.01
# episode: 366/1000, score: 9, e: 0.01
# episode: 367/1000, score: 8, e: 0.01
# episode: 368/1000, score: 9, e: 0.01
# episode: 369/1000, score: 9, e: 0.01
# episode: 370/1000, score: 9, e: 0.01
# episode: 371/1000, score: 8, e: 0.01
# episode: 372/1000, score: 8, e: 0.01
# episode: 373/1000, score: 24, e: 0.01
# episode: 374/1000, score: 29, e: 0.01
# episode: 375/1000, score: 35, e: 0.01
# episode: 376/1000, score: 45, e: 0.01
# episode: 377/1000, score: 39, e: 0.01
# episode: 378/1000, score: 49, e: 0.01
# episode: 379/1000, score: 74, e: 0.01
# episode: 380/1000, score: 126, e: 0.01
# episode: 381/1000, score: 122, e: 0.01
# episode: 382/1000, score: 133, e: 0.01
# episode: 383/1000, score: 87, e: 0.01
# episode: 384/1000, score: 64, e: 0.01
# episode: 385/1000, score: 499, e: 0.01
# episode: 386/1000, score: 330, e: 0.01
# episode: 387/1000, score: 164, e: 0.01
# episode: 388/1000, score: 131, e: 0.01
# episode: 389/1000, score: 10, e: 0.01
# episode: 390/1000, score: 144, e: 0.01
# episode: 391/1000, score: 127, e: 0.01
# episode: 392/1000, score: 499, e: 0.01
# episode: 393/1000, score: 92, e: 0.01
# episode: 394/1000, score: 113, e: 0.01
# episode: 395/1000, score: 94, e: 0.01
# episode: 396/1000, score: 331, e: 0.01
# episode: 397/1000, score: 98, e: 0.01
# episode: 398/1000, score: 130, e: 0.01
# episode: 399/1000, score: 87, e: 0.01
# episode: 400/1000, score: 96, e: 0.01
# episode: 401/1000, score: 47, e: 0.01
# episode: 402/1000, score: 68, e: 0.01
# episode: 403/1000, score: 131, e: 0.01
# episode: 404/1000, score: 118, e: 0.01
# episode: 405/1000, score: 155, e: 0.01
# episode: 406/1000, score: 158, e: 0.01
# episode: 407/1000, score: 140, e: 0.01
# episode: 408/1000, score: 141, e: 0.01
# episode: 409/1000, score: 165, e: 0.01
# episode: 410/1000, score: 499, e: 0.01
# episode: 411/1000, score: 71, e: 0.01
# episode: 412/1000, score: 202, e: 0.01
# episode: 413/1000, score: 139, e: 0.01
# episode: 414/1000, score: 128, e: 0.01
# episode: 415/1000, score: 499, e: 0.01
# episode: 416/1000, score: 239, e: 0.01
# episode: 417/1000, score: 10, e: 0.01
# episode: 418/1000, score: 11, e: 0.01
# episode: 419/1000, score: 499, e: 0.01
# episode: 420/1000, score: 446, e: 0.01
# episode: 421/1000, score: 246, e: 0.01
# episode: 422/1000, score: 135, e: 0.01
# episode: 423/1000, score: 181, e: 0.01
# episode: 424/1000, score: 499, e: 0.01
# episode: 425/1000, score: 258, e: 0.01
# episode: 426/1000, score: 263, e: 0.01
# episode: 427/1000, score: 499, e: 0.01
# episode: 428/1000, score: 164, e: 0.01
# episode: 429/1000, score: 446, e: 0.01
# episode: 430/1000, score: 9, e: 0.01
# episode: 431/1000, score: 10, e: 0.01
# episode: 432/1000, score: 8, e: 0.01
# episode: 433/1000, score: 165, e: 0.01
# episode: 434/1000, score: 149, e: 0.01
# episode: 435/1000, score: 499, e: 0.01
# episode: 436/1000, score: 499, e: 0.01
# episode: 437/1000, score: 303, e: 0.01
# episode: 438/1000, score: 8, e: 0.01
# episode: 439/1000, score: 499, e: 0.01
# episode: 440/1000, score: 216, e: 0.01
# episode: 441/1000, score: 8, e: 0.01
# episode: 442/1000, score: 10, e: 0.01
# episode: 443/1000, score: 8, e: 0.01
# episode: 444/1000, score: 8, e: 0.01
# episode: 445/1000, score: 8, e: 0.01
# episode: 446/1000, score: 9, e: 0.01
# episode: 447/1000, score: 9, e: 0.01
# episode: 448/1000, score: 8, e: 0.01
# episode: 449/1000, score: 9, e: 0.01
# episode: 450/1000, score: 8, e: 0.01
# episode: 451/1000, score: 8, e: 0.01
# episode: 452/1000, score: 7, e: 0.01
# episode: 453/1000, score: 9, e: 0.01
# episode: 454/1000, score: 8, e: 0.01
# episode: 455/1000, score: 9, e: 0.01
# episode: 456/1000, score: 9, e: 0.01
# episode: 457/1000, score: 9, e: 0.01
# episode: 458/1000, score: 8, e: 0.01
# episode: 459/1000, score: 8, e: 0.01
# episode: 460/1000, score: 9, e: 0.01
# episode: 461/1000, score: 30, e: 0.01
# episode: 462/1000, score: 17, e: 0.01
# episode: 463/1000, score: 86, e: 0.01
# episode: 464/1000, score: 130, e: 0.01
# episode: 465/1000, score: 109, e: 0.01
# episode: 466/1000, score: 41, e: 0.01
# episode: 467/1000, score: 110, e: 0.01
# episode: 468/1000, score: 94, e: 0.01
# episode: 469/1000, score: 296, e: 0.01
# episode: 470/1000, score: 107, e: 0.01
# episode: 471/1000, score: 171, e: 0.01
# episode: 472/1000, score: 70, e: 0.01
# episode: 473/1000, score: 133, e: 0.01
# episode: 474/1000, score: 100, e: 0.01
# episode: 475/1000, score: 120, e: 0.01
# episode: 476/1000, score: 174, e: 0.01
# episode: 477/1000, score: 142, e: 0.01
# episode: 478/1000, score: 53, e: 0.01
# episode: 479/1000, score: 28, e: 0.01
# episode: 480/1000, score: 9, e: 0.01
# episode: 481/1000, score: 8, e: 0.01
# episode: 482/1000, score: 8, e: 0.01
# episode: 483/1000, score: 8, e: 0.01
# episode: 484/1000, score: 33, e: 0.01
# episode: 485/1000, score: 192, e: 0.01
# episode: 486/1000, score: 115, e: 0.01
# episode: 487/1000, score: 124, e: 0.01
# episode: 488/1000, score: 102, e: 0.01
# episode: 489/1000, score: 119, e: 0.01
# episode: 490/1000, score: 131, e: 0.01
# episode: 491/1000, score: 103, e: 0.01
# episode: 492/1000, score: 144, e: 0.01
# episode: 493/1000, score: 169, e: 0.01
# episode: 494/1000, score: 114, e: 0.01
# episode: 495/1000, score: 171, e: 0.01
# episode: 496/1000, score: 111, e: 0.01
# episode: 497/1000, score: 291, e: 0.01
# episode: 498/1000, score: 150, e: 0.01
# episode: 499/1000, score: 78, e: 0.01
# episode: 500/1000, score: 160, e: 0.01
# episode: 501/1000, score: 69, e: 0.01
# episode: 502/1000, score: 32, e: 0.01
# episode: 503/1000, score: 8, e: 0.01
# episode: 504/1000, score: 148, e: 0.01
# episode: 505/1000, score: 60, e: 0.01
# episode: 506/1000, score: 62, e: 0.01
# episode: 507/1000, score: 98, e: 0.01
# episode: 508/1000, score: 201, e: 0.01
# episode: 509/1000, score: 104, e: 0.01
# episode: 510/1000, score: 302, e: 0.01
# episode: 511/1000, score: 128, e: 0.01
# episode: 512/1000, score: 121, e: 0.01
# episode: 513/1000, score: 166, e: 0.01
# episode: 514/1000, score: 137, e: 0.01
# episode: 515/1000, score: 111, e: 0.01
# episode: 516/1000, score: 464, e: 0.01
# episode: 517/1000, score: 117, e: 0.01
# episode: 518/1000, score: 143, e: 0.01
# episode: 519/1000, score: 110, e: 0.01
# episode: 520/1000, score: 185, e: 0.01
# episode: 521/1000, score: 322, e: 0.01
# episode: 522/1000, score: 164, e: 0.01
# episode: 523/1000, score: 127, e: 0.01
# episode: 524/1000, score: 91, e: 0.01
# episode: 525/1000, score: 233, e: 0.01
# episode: 526/1000, score: 34, e: 0.01
# episode: 527/1000, score: 9, e: 0.01
# episode: 528/1000, score: 9, e: 0.01
# episode: 529/1000, score: 8, e: 0.01
# episode: 530/1000, score: 7, e: 0.01
# episode: 531/1000, score: 7, e: 0.01
# episode: 532/1000, score: 7, e: 0.01
# episode: 533/1000, score: 8, e: 0.01
# episode: 534/1000, score: 8, e: 0.01
# episode: 535/1000, score: 8, e: 0.01
# episode: 536/1000, score: 8, e: 0.01
# episode: 537/1000, score: 8, e: 0.01
# episode: 538/1000, score: 8, e: 0.01
# episode: 539/1000, score: 9, e: 0.01
# episode: 540/1000, score: 8, e: 0.01
# episode: 541/1000, score: 9, e: 0.01
# episode: 542/1000, score: 9, e: 0.01
# episode: 543/1000, score: 11, e: 0.01
# episode: 544/1000, score: 17, e: 0.01
# episode: 545/1000, score: 8, e: 0.01
# episode: 546/1000, score: 8, e: 0.01
# episode: 547/1000, score: 8, e: 0.01
# episode: 548/1000, score: 8, e: 0.01
# episode: 549/1000, score: 9, e: 0.01
# episode: 550/1000, score: 10, e: 0.01
# episode: 551/1000, score: 13, e: 0.01
# episode: 552/1000, score: 17, e: 0.01
# episode: 553/1000, score: 23, e: 0.01
# episode: 554/1000, score: 53, e: 0.01
# episode: 555/1000, score: 24, e: 0.01
# episode: 556/1000, score: 17, e: 0.01
# episode: 557/1000, score: 20, e: 0.01
# episode: 558/1000, score: 13, e: 0.01
# episode: 559/1000, score: 19, e: 0.01
# episode: 560/1000, score: 29, e: 0.01
# episode: 561/1000, score: 103, e: 0.01
# episode: 562/1000, score: 16, e: 0.01
# episode: 563/1000, score: 93, e: 0.01
# episode: 564/1000, score: 139, e: 0.01
# episode: 565/1000, score: 499, e: 0.01
# episode: 566/1000, score: 167, e: 0.01
# episode: 567/1000, score: 22, e: 0.01
# episode: 568/1000, score: 338, e: 0.01
# episode: 569/1000, score: 205, e: 0.01
# episode: 570/1000, score: 205, e: 0.01
# episode: 571/1000, score: 170, e: 0.01
# episode: 572/1000, score: 311, e: 0.01
# episode: 573/1000, score: 219, e: 0.01
# episode: 574/1000, score: 215, e: 0.01
# episode: 575/1000, score: 286, e: 0.01
# episode: 576/1000, score: 277, e: 0.01
# episode: 577/1000, score: 277, e: 0.01
# episode: 578/1000, score: 30, e: 0.01
# episode: 579/1000, score: 209, e: 0.01
# episode: 580/1000, score: 273, e: 0.01
# episode: 581/1000, score: 226, e: 0.01
# episode: 582/1000, score: 398, e: 0.01
# episode: 583/1000, score: 294, e: 0.01
# episode: 584/1000, score: 226, e: 0.01
# episode: 585/1000, score: 264, e: 0.01
# episode: 586/1000, score: 155, e: 0.01
# episode: 587/1000, score: 51, e: 0.01
# episode: 588/1000, score: 10, e: 0.01
# episode: 589/1000, score: 8, e: 0.01
# episode: 590/1000, score: 8, e: 0.01
# episode: 591/1000, score: 9, e: 0.01
# episode: 592/1000, score: 14, e: 0.01
# episode: 593/1000, score: 101, e: 0.01
# episode: 594/1000, score: 42, e: 0.01
# episode: 595/1000, score: 125, e: 0.01
# episode: 596/1000, score: 171, e: 0.01
# episode: 597/1000, score: 130, e: 0.01
# episode: 598/1000, score: 15, e: 0.01
# episode: 599/1000, score: 45, e: 0.01
# episode: 600/1000, score: 120, e: 0.01
# episode: 601/1000, score: 84, e: 0.01
# episode: 602/1000, score: 81, e: 0.01
# episode: 603/1000, score: 151, e: 0.01
# episode: 604/1000, score: 153, e: 0.01
# episode: 605/1000, score: 186, e: 0.01
# episode: 606/1000, score: 177, e: 0.01
# episode: 607/1000, score: 149, e: 0.01
# episode: 608/1000, score: 181, e: 0.01
# episode: 609/1000, score: 189, e: 0.01
# episode: 610/1000, score: 223, e: 0.01
# episode: 611/1000, score: 303, e: 0.01
# episode: 612/1000, score: 154, e: 0.01
# episode: 613/1000, score: 155, e: 0.01
# episode: 614/1000, score: 177, e: 0.01
# episode: 615/1000, score: 61, e: 0.01
# episode: 616/1000, score: 156, e: 0.01
# episode: 617/1000, score: 58, e: 0.01
# episode: 618/1000, score: 27, e: 0.01
# episode: 619/1000, score: 499, e: 0.01
# episode: 620/1000, score: 58, e: 0.01
# episode: 621/1000, score: 145, e: 0.01
# episode: 622/1000, score: 499, e: 0.01
# episode: 623/1000, score: 309, e: 0.01
# episode: 624/1000, score: 266, e: 0.01
# episode: 625/1000, score: 296, e: 0.01
# episode: 626/1000, score: 357, e: 0.01
# episode: 627/1000, score: 499, e: 0.01
# episode: 628/1000, score: 138, e: 0.01
# episode: 629/1000, score: 499, e: 0.01
# episode: 630/1000, score: 499, e: 0.01
# episode: 631/1000, score: 370, e: 0.01
# episode: 632/1000, score: 138, e: 0.01
# episode: 633/1000, score: 123, e: 0.01
# episode: 634/1000, score: 9, e: 0.01
# episode: 635/1000, score: 10, e: 0.01
# episode: 636/1000, score: 13, e: 0.01
# episode: 637/1000, score: 114, e: 0.01
# episode: 638/1000, score: 354, e: 0.01
# episode: 639/1000, score: 233, e: 0.01
# episode: 640/1000, score: 218, e: 0.01
# episode: 641/1000, score: 84, e: 0.01
# episode: 642/1000, score: 166, e: 0.01
# episode: 643/1000, score: 226, e: 0.01
# episode: 644/1000, score: 499, e: 0.01
# episode: 645/1000, score: 422, e: 0.01
# episode: 646/1000, score: 13, e: 0.01
# episode: 647/1000, score: 9, e: 0.01
# episode: 648/1000, score: 8, e: 0.01
# episode: 649/1000, score: 8, e: 0.01
# episode: 650/1000, score: 9, e: 0.01
# episode: 651/1000, score: 8, e: 0.01
# episode: 652/1000, score: 9, e: 0.01
# episode: 653/1000, score: 9, e: 0.01
# episode: 654/1000, score: 8, e: 0.01
# episode: 655/1000, score: 9, e: 0.01
# episode: 656/1000, score: 8, e: 0.01
# episode: 657/1000, score: 9, e: 0.01
# episode: 658/1000, score: 9, e: 0.01
# episode: 659/1000, score: 54, e: 0.01
# episode: 660/1000, score: 499, e: 0.01
# episode: 661/1000, score: 385, e: 0.01
# episode: 662/1000, score: 223, e: 0.01
# episode: 663/1000, score: 193, e: 0.01
# episode: 664/1000, score: 350, e: 0.01
# episode: 665/1000, score: 499, e: 0.01
# episode: 666/1000, score: 134, e: 0.01
# episode: 667/1000, score: 486, e: 0.01
# episode: 668/1000, score: 499, e: 0.01
# episode: 669/1000, score: 373, e: 0.01
# episode: 670/1000, score: 159, e: 0.01
# episode: 671/1000, score: 389, e: 0.01
# episode: 672/1000, score: 145, e: 0.01
# episode: 673/1000, score: 139, e: 0.01
# episode: 674/1000, score: 425, e: 0.01
# episode: 675/1000, score: 234, e: 0.01
# episode: 676/1000, score: 301, e: 0.01
# episode: 677/1000, score: 288, e: 0.01
# episode: 678/1000, score: 216, e: 0.01
# episode: 679/1000, score: 26, e: 0.01
# episode: 680/1000, score: 8, e: 0.01
# episode: 681/1000, score: 21, e: 0.01
# episode: 682/1000, score: 8, e: 0.01
# episode: 683/1000, score: 8, e: 0.01
# episode: 684/1000, score: 9, e: 0.01
# episode: 685/1000, score: 7, e: 0.01
# episode: 686/1000, score: 9, e: 0.01
# episode: 687/1000, score: 105, e: 0.01
# episode: 688/1000, score: 152, e: 0.01
# episode: 689/1000, score: 141, e: 0.01
# episode: 690/1000, score: 20, e: 0.01
# episode: 691/1000, score: 145, e: 0.01
# episode: 692/1000, score: 178, e: 0.01
# episode: 693/1000, score: 356, e: 0.01
# episode: 694/1000, score: 312, e: 0.01
# episode: 695/1000, score: 290, e: 0.01
# episode: 696/1000, score: 265, e: 0.01
# episode: 697/1000, score: 120, e: 0.01
# episode: 698/1000, score: 94, e: 0.01
# episode: 699/1000, score: 244, e: 0.01
# episode: 700/1000, score: 75, e: 0.01
# episode: 701/1000, score: 100, e: 0.01
# episode: 702/1000, score: 178, e: 0.01
# episode: 703/1000, score: 202, e: 0.01
# episode: 704/1000, score: 174, e: 0.01
# episode: 705/1000, score: 143, e: 0.01
# episode: 706/1000, score: 85, e: 0.01
# episode: 707/1000, score: 63, e: 0.01
# episode: 708/1000, score: 135, e: 0.01
# episode: 709/1000, score: 132, e: 0.01
# episode: 710/1000, score: 26, e: 0.01
# episode: 711/1000, score: 96, e: 0.01
# episode: 712/1000, score: 151, e: 0.01
# episode: 713/1000, score: 333, e: 0.01
# episode: 714/1000, score: 177, e: 0.01
# episode: 715/1000, score: 194, e: 0.01
# episode: 716/1000, score: 174, e: 0.01
# episode: 717/1000, score: 201, e: 0.01
# episode: 718/1000, score: 143, e: 0.01
# episode: 719/1000, score: 499, e: 0.01
# episode: 720/1000, score: 249, e: 0.01
# episode: 721/1000, score: 158, e: 0.01
# episode: 722/1000, score: 24, e: 0.01
# episode: 723/1000, score: 169, e: 0.01
# episode: 724/1000, score: 99, e: 0.01
# episode: 725/1000, score: 9, e: 0.01
# episode: 726/1000, score: 21, e: 0.01
# episode: 727/1000, score: 37, e: 0.01
# episode: 728/1000, score: 9, e: 0.01
# episode: 729/1000, score: 7, e: 0.01
# episode: 730/1000, score: 8, e: 0.01
# episode: 731/1000, score: 8, e: 0.01
# episode: 732/1000, score: 9, e: 0.01
# episode: 733/1000, score: 9, e: 0.01
# episode: 734/1000, score: 9, e: 0.01
# episode: 735/1000, score: 9, e: 0.01
# episode: 736/1000, score: 7, e: 0.01
# episode: 737/1000, score: 7, e: 0.01
# episode: 738/1000, score: 8, e: 0.01
# episode: 739/1000, score: 9, e: 0.01
# episode: 740/1000, score: 10, e: 0.01
# episode: 741/1000, score: 85, e: 0.01
# episode: 742/1000, score: 82, e: 0.01
# episode: 743/1000, score: 105, e: 0.01
# episode: 744/1000, score: 84, e: 0.01
# episode: 745/1000, score: 84, e: 0.01
# episode: 746/1000, score: 112, e: 0.01
# episode: 747/1000, score: 157, e: 0.01
# episode: 748/1000, score: 113, e: 0.01
# episode: 749/1000, score: 255, e: 0.01
# episode: 750/1000, score: 409, e: 0.01
# episode: 751/1000, score: 499, e: 0.01
# episode: 752/1000, score: 499, e: 0.01
# episode: 753/1000, score: 338, e: 0.01
# episode: 754/1000, score: 157, e: 0.01
# episode: 755/1000, score: 336, e: 0.01
# episode: 756/1000, score: 115, e: 0.01
# episode: 757/1000, score: 296, e: 0.01
# episode: 758/1000, score: 198, e: 0.01
# episode: 759/1000, score: 217, e: 0.01
# episode: 760/1000, score: 321, e: 0.01
# episode: 761/1000, score: 253, e: 0.01
# episode: 762/1000, score: 175, e: 0.01
# episode: 763/1000, score: 309, e: 0.01
# episode: 764/1000, score: 9, e: 0.01
# episode: 765/1000, score: 11, e: 0.01
# episode: 766/1000, score: 68, e: 0.01
# episode: 767/1000, score: 19, e: 0.01
# episode: 768/1000, score: 61, e: 0.01
# episode: 769/1000, score: 499, e: 0.01
# episode: 770/1000, score: 453, e: 0.01
# episode: 771/1000, score: 499, e: 0.01
# episode: 772/1000, score: 479, e: 0.01
# episode: 773/1000, score: 208, e: 0.01
# episode: 774/1000, score: 118, e: 0.01
# episode: 775/1000, score: 112, e: 0.01
# episode: 776/1000, score: 18, e: 0.01
# episode: 777/1000, score: 9, e: 0.01
# episode: 778/1000, score: 8, e: 0.01
# episode: 779/1000, score: 8, e: 0.01
# episode: 780/1000, score: 7, e: 0.01
# episode: 781/1000, score: 8, e: 0.01
# episode: 782/1000, score: 8, e: 0.01
# episode: 783/1000, score: 8, e: 0.01
# episode: 784/1000, score: 7, e: 0.01
# episode: 785/1000, score: 9, e: 0.01
# episode: 786/1000, score: 9, e: 0.01
# episode: 787/1000, score: 9, e: 0.01
# episode: 788/1000, score: 7, e: 0.01
# episode: 789/1000, score: 9, e: 0.01
# episode: 790/1000, score: 9, e: 0.01
# episode: 791/1000, score: 9, e: 0.01
# episode: 792/1000, score: 8, e: 0.01
# episode: 793/1000, score: 10, e: 0.01
# episode: 794/1000, score: 9, e: 0.01
# episode: 795/1000, score: 9, e: 0.01
# episode: 796/1000, score: 8, e: 0.01
# episode: 797/1000, score: 9, e: 0.01
# episode: 798/1000, score: 8, e: 0.01
# episode: 799/1000, score: 9, e: 0.01
# episode: 800/1000, score: 8, e: 0.01
# episode: 801/1000, score: 11, e: 0.01
# episode: 802/1000, score: 19, e: 0.01
# episode: 803/1000, score: 27, e: 0.01
# episode: 804/1000, score: 27, e: 0.01
# episode: 805/1000, score: 19, e: 0.01
# episode: 806/1000, score: 18, e: 0.01
# episode: 807/1000, score: 19, e: 0.01
# episode: 808/1000, score: 21, e: 0.01
# episode: 809/1000, score: 25, e: 0.01
# episode: 810/1000, score: 16, e: 0.01
# episode: 811/1000, score: 19, e: 0.01
# episode: 812/1000, score: 19, e: 0.01
# episode: 813/1000, score: 18, e: 0.01
# episode: 814/1000, score: 16, e: 0.01
# episode: 815/1000, score: 25, e: 0.01
# episode: 816/1000, score: 26, e: 0.01
# episode: 817/1000, score: 26, e: 0.01
# episode: 818/1000, score: 14, e: 0.01
# episode: 819/1000, score: 11, e: 0.01
# episode: 820/1000, score: 24, e: 0.01
# episode: 821/1000, score: 22, e: 0.01
# episode: 822/1000, score: 9, e: 0.01
# episode: 823/1000, score: 8, e: 0.01
# episode: 824/1000, score: 8, e: 0.01
# episode: 825/1000, score: 8, e: 0.01
# episode: 826/1000, score: 8, e: 0.01
# episode: 827/1000, score: 8, e: 0.01
# episode: 828/1000, score: 7, e: 0.01
# episode: 829/1000, score: 8, e: 0.01
# episode: 830/1000, score: 8, e: 0.01
# episode: 831/1000, score: 11, e: 0.01
# episode: 832/1000, score: 23, e: 0.01
# episode: 833/1000, score: 18, e: 0.01
# episode: 834/1000, score: 7, e: 0.01
# episode: 835/1000, score: 8, e: 0.01
# episode: 836/1000, score: 39, e: 0.01
# episode: 837/1000, score: 24, e: 0.01
# episode: 838/1000, score: 14, e: 0.01
# episode: 839/1000, score: 8, e: 0.01
# episode: 840/1000, score: 31, e: 0.01
# episode: 841/1000, score: 11, e: 0.01
# episode: 842/1000, score: 73, e: 0.01
# episode: 843/1000, score: 28, e: 0.01
# episode: 844/1000, score: 68, e: 0.01
# episode: 845/1000, score: 10, e: 0.01
# episode: 846/1000, score: 70, e: 0.01
# episode: 847/1000, score: 20, e: 0.01
# episode: 848/1000, score: 111, e: 0.01
# episode: 849/1000, score: 129, e: 0.01
# episode: 850/1000, score: 242, e: 0.01
# episode: 851/1000, score: 207, e: 0.01
# episode: 852/1000, score: 398, e: 0.01
# episode: 853/1000, score: 294, e: 0.01
# episode: 854/1000, score: 248, e: 0.01
# episode: 855/1000, score: 340, e: 0.01
# episode: 856/1000, score: 74, e: 0.01
# episode: 857/1000, score: 9, e: 0.01
# episode: 858/1000, score: 8, e: 0.01
# episode: 859/1000, score: 9, e: 0.01
# episode: 860/1000, score: 8, e: 0.01
# episode: 861/1000, score: 9, e: 0.01
# episode: 862/1000, score: 9, e: 0.01
# episode: 863/1000, score: 8, e: 0.01
# episode: 864/1000, score: 9, e: 0.01
# episode: 865/1000, score: 9, e: 0.01
# episode: 866/1000, score: 9, e: 0.01
# episode: 867/1000, score: 9, e: 0.01
# episode: 868/1000, score: 9, e: 0.01
# episode: 869/1000, score: 9, e: 0.01
# episode: 870/1000, score: 8, e: 0.01
# episode: 871/1000, score: 9, e: 0.01
# episode: 872/1000, score: 8, e: 0.01
# episode: 873/1000, score: 8, e: 0.01
# episode: 874/1000, score: 8, e: 0.01
# episode: 875/1000, score: 8, e: 0.01
# episode: 876/1000, score: 8, e: 0.01
# episode: 877/1000, score: 7, e: 0.01
# episode: 878/1000, score: 9, e: 0.01
# episode: 879/1000, score: 9, e: 0.01
# episode: 880/1000, score: 7, e: 0.01
# episode: 881/1000, score: 9, e: 0.01
# episode: 882/1000, score: 9, e: 0.01
# episode: 883/1000, score: 23, e: 0.01
# episode: 884/1000, score: 9, e: 0.01
# episode: 885/1000, score: 9, e: 0.01
# episode: 886/1000, score: 9, e: 0.01
# episode: 887/1000, score: 9, e: 0.01
# episode: 888/1000, score: 9, e: 0.01
# episode: 889/1000, score: 8, e: 0.01
# episode: 890/1000, score: 9, e: 0.01
# episode: 891/1000, score: 8, e: 0.01
# episode: 892/1000, score: 8, e: 0.01
# episode: 893/1000, score: 7, e: 0.01
# episode: 894/1000, score: 7, e: 0.01
# episode: 895/1000, score: 8, e: 0.01
# episode: 896/1000, score: 7, e: 0.01
# episode: 897/1000, score: 8, e: 0.01
# episode: 898/1000, score: 7, e: 0.01
# episode: 899/1000, score: 8, e: 0.01
# episode: 900/1000, score: 8, e: 0.01
# episode: 901/1000, score: 9, e: 0.01
# episode: 902/1000, score: 36, e: 0.01
# episode: 903/1000, score: 18, e: 0.01
# episode: 904/1000, score: 15, e: 0.01
# episode: 905/1000, score: 24, e: 0.01
# episode: 906/1000, score: 20, e: 0.01
# episode: 907/1000, score: 31, e: 0.01
# episode: 908/1000, score: 27, e: 0.01
# episode: 909/1000, score: 24, e: 0.01
# episode: 910/1000, score: 27, e: 0.01
# episode: 911/1000, score: 25, e: 0.01
# episode: 912/1000, score: 21, e: 0.01
# episode: 913/1000, score: 21, e: 0.01
# episode: 914/1000, score: 29, e: 0.01
# episode: 915/1000, score: 32, e: 0.01
# episode: 916/1000, score: 46, e: 0.01
# episode: 917/1000, score: 114, e: 0.01
# episode: 918/1000, score: 55, e: 0.01
# episode: 919/1000, score: 65, e: 0.01
# episode: 920/1000, score: 59, e: 0.01
# episode: 921/1000, score: 132, e: 0.01
# episode: 922/1000, score: 113, e: 0.01
# episode: 923/1000, score: 160, e: 0.01
# episode: 924/1000, score: 210, e: 0.01
# episode: 925/1000, score: 223, e: 0.01
# episode: 926/1000, score: 217, e: 0.01
# episode: 927/1000, score: 174, e: 0.01
# episode: 928/1000, score: 262, e: 0.01
# episode: 929/1000, score: 140, e: 0.01
# episode: 930/1000, score: 24, e: 0.01
# episode: 931/1000, score: 8, e: 0.01
# episode: 932/1000, score: 9, e: 0.01
# episode: 933/1000, score: 9, e: 0.01
# episode: 934/1000, score: 248, e: 0.01
# episode: 935/1000, score: 280, e: 0.01
# episode: 936/1000, score: 365, e: 0.01
# episode: 937/1000, score: 224, e: 0.01
# episode: 938/1000, score: 236, e: 0.01
# episode: 939/1000, score: 387, e: 0.01
# episode: 940/1000, score: 60, e: 0.01
# episode: 941/1000, score: 248, e: 0.01
# episode: 942/1000, score: 212, e: 0.01
# episode: 943/1000, score: 73, e: 0.01
# episode: 944/1000, score: 9, e: 0.01
# episode: 945/1000, score: 7, e: 0.01
# episode: 946/1000, score: 9, e: 0.01
# episode: 947/1000, score: 8, e: 0.01
# episode: 948/1000, score: 8, e: 0.01
# episode: 949/1000, score: 8, e: 0.01
# episode: 950/1000, score: 7, e: 0.01
# episode: 951/1000, score: 9, e: 0.01
# episode: 952/1000, score: 10, e: 0.01
# episode: 953/1000, score: 11, e: 0.01
# episode: 954/1000, score: 476, e: 0.01
# episode: 955/1000, score: 135, e: 0.01
# episode: 956/1000, score: 158, e: 0.01
# episode: 957/1000, score: 70, e: 0.01
# episode: 958/1000, score: 12, e: 0.01
# episode: 959/1000, score: 192, e: 0.01
# episode: 960/1000, score: 163, e: 0.01
# episode: 961/1000, score: 182, e: 0.01
# episode: 962/1000, score: 188, e: 0.01
# episode: 963/1000, score: 175, e: 0.01
# episode: 964/1000, score: 184, e: 0.01
# episode: 965/1000, score: 204, e: 0.01
# episode: 966/1000, score: 28, e: 0.01
# episode: 967/1000, score: 126, e: 0.01
# episode: 968/1000, score: 499, e: 0.01
# episode: 969/1000, score: 315, e: 0.01
# episode: 970/1000, score: 9, e: 0.01
# episode: 971/1000, score: 12, e: 0.01
# episode: 972/1000, score: 26, e: 0.01
# episode: 973/1000, score: 42, e: 0.01
# episode: 974/1000, score: 61, e: 0.01
# episode: 975/1000, score: 14, e: 0.01
# episode: 976/1000, score: 8, e: 0.01
# episode: 977/1000, score: 34, e: 0.01
# episode: 978/1000, score: 460, e: 0.01
# episode: 979/1000, score: 141, e: 0.01
# episode: 980/1000, score: 499, e: 0.01
# episode: 981/1000, score: 135, e: 0.01
# episode: 982/1000, score: 151, e: 0.01
# episode: 983/1000, score: 335, e: 0.01
# episode: 984/1000, score: 428, e: 0.01
# episode: 985/1000, score: 499, e: 0.01
# episode: 986/1000, score: 155, e: 0.01
# episode: 987/1000, score: 430, e: 0.01
# episode: 988/1000, score: 375, e: 0.01
# episode: 989/1000, score: 499, e: 0.01
# episode: 990/1000, score: 137, e: 0.01
# episode: 991/1000, score: 17, e: 0.01
# episode: 992/1000, score: 381, e: 0.01
# episode: 993/1000, score: 180, e: 0.01
# episode: 994/1000, score: 295, e: 0.01
# episode: 995/1000, score: 143, e: 0.01
# episode: 996/1000, score: 143, e: 0.01
# episode: 997/1000, score: 170, e: 0.01
# episode: 998/1000, score: 19, e: 0.01
# episode: 999/1000, score: 258, e: 0.01
